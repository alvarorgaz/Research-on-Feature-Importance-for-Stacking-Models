# %% [markdown]
# #### Import packages

# %%
import warnings
warnings.filterwarnings('ignore')
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# #### Read data

# %%
data2014 = pd.read_csv('Data/Data2014.csv',sep=',',na_values=['','N/A','Not eligible for coverage / N/A','NA'])
data2016 = pd.read_csv('Data/Data2016.csv',sep=',',na_values=['','N/A','Not eligible for coverage / N/A','NA'])

# %% [markdown]
# #### Concatenate data

# %%
features2014 = ['Age','anonymity','benefits','care_options','coworkers','family_history','Gender','leave',
                'mental_health_consequence','mental_health_interview','mental_vs_physical','no_employees','obs_consequence',
                'phys_health_consequence','phys_health_interview','remote_work','seek_help','self_employed','supervisor',
                'tech_company','treatment','wellness_program','work_interfere']
features2016 = ['What is your age?',
                'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?',
                'Does your employer provide mental health benefits as part of healthcare coverage?',
                'Do you know the options for mental health care available under your employer-provided coverage?',
                'Would you feel comfortable discussing a mental health disorder with your coworkers?',
                'Do you have a family history of mental illness?',
                'What is your gender?',
                'If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:',
                'Do you think that discussing a mental health disorder with your employer would have negative consequences?',
                'Would you bring up a mental health issue with a potential employer in an interview?',
                'Do you feel that your employer takes mental health as seriously as physical health?',
                'How many employees does your company or organization have?',
                'Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?',
                'Do you think that discussing a physical health issue with your employer would have negative consequences?',
                'Would you be willing to bring up a physical health issue with a potential employer in an interview?',
                'Do you work remotely?',
                'Do you know local or online resources to seek help for a mental health disorder?',
                'Are you self-employed?',
                'Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?',
                'Is your employer primarily a tech company/organization?',
                'Have you ever sought treatment for a mental health issue from a mental health professional?',
                'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?',
                'If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?']
data2014 = data2014[features2014]
data2016 = data2016[features2016]
data2016.columns = features2014
data = pd.concat([data2014,data2016],axis=0).reset_index(drop=True)

# %%
data.shape
data.T
# Out:
# (2692, 23)
#                                     0               1                   2     \
# Age                                   37              44                  32
# anonymity                            Yes      Don't know          Don't know
# benefits                             Yes      Don't know                  No
# care_options                    Not sure              No                  No
# coworkers                   Some of them              No                 Yes
# family_history                        No              No                  No
# Gender                            Female               M                Male
# leave                      Somewhat easy      Don't know  Somewhat difficult
# mental_health_consequence             No           Maybe                  No
# mental_health_interview               No              No                 Yes
# mental_vs_physical                   Yes      Don't know                  No
# no_employees                        6-25  More than 1000                6-25
# obs_consequence                       No              No                  No
# phys_health_consequence               No              No                  No
# phys_health_interview              Maybe              No                 Yes
# remote_work                           No              No                  No
# seek_help                            Yes      Don't know                  No
# self_employed                        NaN             NaN                 NaN
# supervisor                           Yes              No                 Yes
# tech_company                         Yes              No                 Yes
# treatment                            Yes              No                  No
# wellness_program                      No      Don't know                  No
# work_interfere                     Often          Rarely              Rarely
#
#                                          3             4           5     \
# Age                                        31            31          33
# anonymity                                  No    Don't know  Don't know
# benefits                                   No           Yes         Yes
# care_options                              Yes            No    Not sure
# coworkers                        Some of them  Some of them         Yes
# family_history                            Yes            No         Yes
# Gender                                   Male          Male        Male
# leave                      Somewhat difficult    Don't know  Don't know
# mental_health_consequence                 Yes            No          No
# mental_health_interview                 Maybe           Yes          No
# mental_vs_physical                         No    Don't know  Don't know
# no_employees                           26-100       100-500        6-25
# obs_consequence                           Yes            No          No
# phys_health_consequence                   Yes            No          No
# phys_health_interview                   Maybe           Yes       Maybe
# remote_work                                No           Yes          No
# seek_help                                  No    Don't know  Don't know
# self_employed                             NaN           NaN         NaN
# supervisor                                 No           Yes         Yes
# tech_company                              Yes           Yes         Yes
# treatment                                 Yes            No          No
# wellness_program                           No    Don't know          No
# work_interfere                          Often         Never   Sometimes
#
#                                          6           7               8     \
# Age                                        35          39              42
# anonymity                                  No         Yes              No
# benefits                                   No          No             Yes
# care_options                               No         Yes             Yes
# coworkers                        Some of them          No             Yes
# family_history                            Yes          No             Yes
# Gender                                 Female           M          Female
# leave                      Somewhat difficult  Don't know  Very difficult
# mental_health_consequence               Maybe          No           Maybe
# mental_health_interview                    No          No              No
# mental_vs_physical                 Don't know          No              No
# no_employees                              1-5         1-5         100-500
# obs_consequence                            No          No              No
# phys_health_consequence                 Maybe          No              No
# phys_health_interview                      No          No           Maybe
# remote_work                               Yes         Yes              No
# seek_help                                  No          No              No
# self_employed                             NaN         NaN             NaN
# supervisor                                 No          No             Yes
# tech_company                              Yes         Yes             Yes
# treatment                                 Yes          No             Yes
# wellness_program                           No          No              No
# work_interfere                      Sometimes       Never       Sometimes
#
#                                  9             ...           \
# Age                                23          ...
# anonymity                  Don't know          ...
# benefits                   Don't know          ...
# care_options                       No          ...
# coworkers                         Yes          ...
# family_history                     No          ...
# Gender                           Male          ...
# leave                      Don't know          ...
# mental_health_consequence          No          ...
# mental_health_interview         Maybe          ...
# mental_vs_physical                Yes          ...
# no_employees                   26-100          ...
# obs_consequence                    No          ...
# phys_health_consequence            No          ...
# phys_health_interview           Maybe          ...
# remote_work                        No          ...
# seek_help                  Don't know          ...
# self_employed                     NaN          ...
# supervisor                        Yes          ...
# tech_company                      Yes          ...
# treatment                          No          ...
# wellness_program           Don't know          ...
# work_interfere                  Never          ...
#
#                                            2682                2683  \
# Age                                          24                  22
# anonymity                          I don't know        I don't know
# benefits                                    Yes                 NaN
# care_options                      I am not sure                 NaN
# coworkers                                    No               Maybe
# family_history                               No        I don't know
# Gender                                     Male              female
# leave                             Somewhat easy  Somewhat difficult
# mental_health_consequence                    No               Maybe
# mental_health_interview                      No               Maybe
# mental_vs_physical                           No        I don't know
# no_employees                            100-500             100-500
# obs_consequence                              No                  No
# phys_health_consequence                      No                  No
# phys_health_interview                     Maybe               Maybe
# remote_work                           Sometimes           Sometimes
# seek_help                                   NaN                 NaN
# self_employed                                 0                   0
# supervisor                                Maybe               Maybe
# tech_company                                  1                   1
# treatment                                     0                   1
# wellness_program                            Yes                  No
# work_interfere             Not applicable to me              Rarely
#
#                                     2684           2685           2686  \
# Age                                   24             26             38
# anonymity                            Yes   I don't know            Yes
# benefits                             Yes   I don't know            Yes
# care_options               I am not sure  I am not sure             No
# coworkers                          Maybe          Maybe            Yes
# family_history              I don't know   I don't know            Yes
# Gender                              Male         Female         female
# leave                      Somewhat easy  Somewhat easy  Somewhat easy
# mental_health_consequence             No          Maybe             No
# mental_health_interview               No          Maybe             No
# mental_vs_physical                   Yes   I don't know            Yes
# no_employees                     100-500        100-500       500-1000
# obs_consequence                       No             No             No
# phys_health_consequence               No             No             No
# phys_health_interview              Maybe          Maybe             No
# remote_work                    Sometimes      Sometimes         Always
# seek_help                            NaN            NaN            NaN
# self_employed                          0              0              0
# supervisor                           Yes          Maybe            Yes
# tech_company                           1              1              1
# treatment                              0              1              1
# wellness_program                     Yes             No             No
# work_interfere                    Rarely         Rarely         Rarely
#
#                                            2687         2688  \
# Age                                          34           56
# anonymity                                   NaN          NaN
# benefits                                    NaN          NaN
# care_options                                NaN          NaN
# coworkers                                   NaN          NaN
# family_history                              Yes          Yes
# Gender                                  Female          MALE
# leave                                       NaN          NaN
# mental_health_consequence                   NaN          NaN
# mental_health_interview                      No           No
# mental_vs_physical                          NaN          NaN
# no_employees                                NaN          NaN
# obs_consequence                             NaN          NaN
# phys_health_consequence                     NaN          NaN
# phys_health_interview                        No        Maybe
# remote_work                           Sometimes    Sometimes
# seek_help                   Yes, I know several  I know some
# self_employed                                 1            1
# supervisor                                  NaN          NaN
# tech_company                                NaN          NaN
# treatment                                     1            0
# wellness_program                            NaN          NaN
# work_interfere             Not applicable to me    Sometimes
#
#                                          2689                2690  \
# Age                                        52                  30
# anonymity                        I don't know        I don't know
# benefits                                  Yes        I don't know
# care_options                              Yes       I am not sure
# coworkers                                 Yes               Maybe
# family_history                            Yes                 Yes
# Gender                                   Male              Female
# leave                      Somewhat difficult  Somewhat difficult
# mental_health_consequence               Maybe               Maybe
# mental_health_interview                    No                  No
# mental_vs_physical               I don't know                  No
# no_employees                          100-500             100-500
# obs_consequence                           Yes                  No
# phys_health_consequence                 Maybe                  No
# phys_health_interview                   Maybe               Maybe
# remote_work                         Sometimes           Sometimes
# seek_help                                 NaN                 NaN
# self_employed                               0                   0
# supervisor                                Yes                 Yes
# tech_company                                1                   0
# treatment                                   1                   0
# wellness_program                          Yes                  No
# work_interfere                         Rarely           Sometimes
#
#                                            2691
# Age                                          25
# anonymity                          I don't know
# benefits                                    Yes
# care_options                                 No
# coworkers                                 Maybe
# family_history                     I don't know
# Gender                               non-binary
# leave                            Very difficult
# mental_health_consequence                 Maybe
# mental_health_interview                      No
# mental_vs_physical                           No
# no_employees                            100-500
# obs_consequence                              No
# phys_health_consequence                      No
# phys_health_interview                     Maybe
# remote_work                           Sometimes
# seek_help                                   NaN
# self_employed                                 0
# supervisor                                Maybe
# tech_company                                  1
# treatment                                     0
# wellness_program                             No
# work_interfere             Not applicable to me
#
# [23 rows x 2692 columns]

# %% [markdown]
# #### Number of unique values by features

# %%
data.nunique()
# Out:
# Age                          64
# anonymity                     4
# benefits                      4
# care_options                  4
# coworkers                     4
# family_history                3
# Gender                       99
# leave                         7
# mental_health_consequence     3
# mental_health_interview       3
# mental_vs_physical            4
# no_employees                  6
# obs_consequence               2
# phys_health_consequence       3
# phys_health_interview         3
# remote_work                   5
# seek_help                     6
# self_employed                 4
# supervisor                    4
# tech_company                  4
# treatment                     4
# wellness_program              4
# work_interfere                5
# dtype: int64

# %% [markdown]
# #### Unique values by features

# %%
for feature in data.columns:
    print(feature,data[feature].unique(),'\n')
# Out:
# Age [         37          44          32          31          33          35
#           39          42          23          29          36          27
#           46          41          34          30          40          38
#           50          24          18          28          26          22
#           19          25          45          21         -29          43
#           56          60          54         329          55 99999999999
#           48          20          57          58          47          62
#           51          65          49       -1726           5          53
#           61           8          11          -1          72          52
#           17          63          99         323           3          66
#           59          15          74          70]
#
# anonymity ['Yes' "Don't know" 'No' "I don't know" nan]
#
# benefits ['Yes' "Don't know" 'No' nan "I don't know"]
#
# care_options ['Not sure' 'No' 'Yes' nan 'I am not sure']
#
# coworkers ['Some of them' 'No' 'Yes' 'Maybe' nan]
#
# family_history ['No' 'Yes' "I don't know"]
#
# Gender ['Female' 'M' 'Male' 'male' 'female' 'm' 'Male-ish' 'maile' 'Trans-female'
#  'Cis Female' 'F' 'something kinda male?' 'Cis Male' 'Woman' 'f' 'Mal'
#  'Male (CIS)' 'queer/she/they' 'non-binary' 'Femake' 'woman' 'Make' 'Nah'
#  'All' 'Enby' 'fluid' 'Genderqueer' 'Female ' 'Androgyne' 'Agender'
#  'cis-female/femme' 'Guy (-ish) ^_^' 'male leaning androgynous' 'Male '
#  'Man' 'Trans woman' 'msle' 'Neuter' 'Female (trans)' 'queer'
#  'Female (cis)' 'Mail' 'cis male' 'A little about you' 'Malr' 'p' 'femail'
#  'Cis Man' 'ostensibly male, unsure what that really means'
#  'I identify as female.' 'female ' 'Bigender' 'Female assigned at birth '
#  'man' 'fm' 'Cis female ' 'Transitioned, M2F' 'Genderfluid (born female)'
#  'Other/Transfeminine' 'Female or Multi-Gender Femme' 'female/woman'
#  'Cis male' 'Male.' 'Androgynous' 'male 9:1 female, roughly' nan
#  'Male (cis)' 'Other' 'nb masculine' 'Cisgender Female' 'Sex is male'
#  'none of your business' 'genderqueer' 'Human' 'Genderfluid'
#  'genderqueer woman' 'mtf' 'Queer' 'Dude' 'Fluid'
#  "I'm a man why didn't you make this a drop down question. You should of asked sex? And I would of answered yes please. Seriously how much text can this take? "
#  'mail' 'M|' 'Male/genderqueer' 'fem' 'Nonbinary' 'male ' 'human'
#  'Female (props for making this a freeform field, though)' ' Female'
#  'Unicorn' 'Male (trans, FtM)' 'Cis-woman' 'cisdude'
#  'Genderflux demi-girl' 'female-bodied; no feelings about gender'
#  'cis man' 'AFAB' 'Transgender woman' 'MALE']
#
# leave ['Somewhat easy' "Don't know" 'Somewhat difficult' 'Very difficult'
#  'Very easy' 'Neither easy nor difficult' nan "I don't know"]
#
# mental_health_consequence ['No' 'Maybe' 'Yes' nan]
#
# mental_health_interview ['No' 'Yes' 'Maybe']
#
# mental_vs_physical ['Yes' "Don't know" 'No' "I don't know" nan]
#
# no_employees ['6-25' 'More than 1000' '26-100' '100-500' '1-5' '500-1000' nan]
#
# obs_consequence ['No' 'Yes' nan]
#
# phys_health_consequence ['No' 'Yes' 'Maybe' nan]
#
# phys_health_interview ['Maybe' 'No' 'Yes']
#
# remote_work ['No' 'Yes' 'Sometimes' 'Never' 'Always']
#
# seek_help ['Yes' "Don't know" 'No' nan 'Yes, I know several' 'I know some'
#  "No, I don't know any"]
#
# self_employed [nan 'Yes' 'No' 0 1]
#
# supervisor ['Yes' 'No' 'Some of them' 'Maybe' nan]
#
# tech_company ['Yes' 'No' 1.0 nan 0.0]
#
# treatment ['Yes' 'No' 0 1]
#
# wellness_program ['No' "Don't know" 'Yes' nan "I don't know"]
#
# work_interfere ['Often' 'Rarely' 'Never' 'Sometimes' nan 'Not applicable to me']

# %% [markdown]
# #### Initial features preprocessing
# - Numerical features: *Age* below 15 years and above 75 as missing values
# - Categorical features: grouping of values

# %%
# Age
data.loc[data['Age']<15,'Age'] = np.nan
data.loc[data['Age']>75,'Age'] = np.nan
# anonymity
data.loc[data['anonymity'].isin(["I don't know","Don't know"]),'anonymity'] = 'Unknown'
# benefits
data.loc[data['benefits'].isin(["I don't know","Don't know"]),'benefits'] = 'Unknown'
# care_options
data.loc[data['care_options'].isin(['I am not sure','Not sure']),'care_options'] = 'Unknown'
# coworkers
data.loc[data['coworkers'].isin(['Some of them','Yes']),'coworkers'] = 'Yes'
# family_history
data.loc[data['family_history'].isin(["I don't know"]),'family_history'] = 'Unknown'
# Gender
female_levels = ['Female','Woman','female','Trans-female','Cis Female','F','f','queer/she/they','Femake','woman','Female ',
                 'cis-female/femme','Trans woman','Female (trans)','Female (cis)','p','femail','I identify as female.',
                 'female ','Female assigned at birth ','fm','Cis female ','Genderfluid (born female)',
                 'Female or Multi-Gender Femme','female/woman','Cisgender Female','genderqueer woman','fem',
                 'Female (props for making this a freeform field, though)',' Female','Cis-woman','Genderflux demi-girl',
                 'female-bodied; no feelings about gender']
male_levels = ['M','MALE','Male','male','m','Male-ish','maile','something kinda male?','Cis Male','Mal','Male (CIS)',
               'Guy (-ish) ^_^','male leaning androgynous','Male ','Man','msle','Mail','cis male','Malr','Cis Man',
               'ostensibly male, unsure what that really means','man','Cis male','Male.','male 9:1 female, roughly','Male (cis)',
               'nb masculine','Sex is male',"I'm a man why didn't you make this a drop down question. You should of asked sex? And I would of answered yes please. Seriously how much text can this take? ",
               'mail','M|','Male/genderqueer','male ','Male (trans, FtM)','cis man','Dude','cisdude']
homosexual_levels = ['non-binary','Make','Nah','All','fluid','Enby','Genderqueer','Androgyne','Agender','Neuter','queer',
                     'A little about you','Bigender','Transitioned, M2F','Other/Transfeminine','Androgynous','Other',
                     'none of your business','genderqueer','Human','Genderfluid','mtf','Queer','Fluid','Nonbinary','human',
                     'Unicorn','AFAB','Transgender woman']
data.loc[data['Gender'].isin(female_levels),'Gender'] = 'Female'
data.loc[data['Gender'].isin(male_levels),'Gender'] = 'Male'
data.loc[data['Gender'].isin(homosexual_levels),'Gender'] = 'Homosexual'
# leave
data.loc[data['leave'].isin(["I don't know","Don't know",'Neither easy nor difficult']),'leave'] = 'Unknown'
data.loc[data['leave'].isin(['Somewhat easy','Very easy']),'leave'] = 'Easy'
data.loc[data['leave'].isin(['Somewhat difficult','Very difficult']),'leave'] = 'Difficult'
# mental_vs_physical
data.loc[data['mental_vs_physical'].isin(["I don't know","Don't know"]),'mental_vs_physical'] = 'Unknown'
# no_employees
data.loc[data['no_employees'].isin(['6-25','1-5']),'no_employees'] = '1-25'
data.loc[data['no_employees'].isin(['100-500','500-1000']),'no_employees'] = '100-1000'
# remote_work
data.loc[data['remote_work'].isin(['Sometimes','Yes','Always']),'remote_work'] = 'Yes'
data.loc[data['remote_work'].isin(['No','Never']),'remote_work'] = 'No'
# seek_help
data.loc[data['seek_help'].isin(["No, I don't know any",'No']),'seek_help'] = 'No'
data.loc[data['seek_help'].isin(["Don't know"]),'seek_help'] = 'Unknown'
data.loc[data['seek_help'].isin(['Yes','Yes, I know several','I know some']),'seek_help'] = 'Yes'
# supervisor
data.loc[data['supervisor'].isin(['Yes','Some of them']),'supervisor'] = 'Yes'
# self_employed
data.loc[data['self_employed']==0,'self_employed'] = 'No'
data.loc[data['self_employed']==1,'self_employed'] = 'Yes'
# tech_company
data.loc[data['tech_company']==0,'tech_company'] = 'No'
data.loc[data['tech_company']==1,'tech_company'] = 'Yes'
# treatment
data.loc[data['treatment'].isin(['No']),'treatment'] = 0
data.loc[data['treatment'].isin(['Yes']),'treatment'] = 1
# wellness_program
data.loc[data['wellness_program'].isin(["I don't know","Don't know"]),'wellness_program'] = 'Unknown'
# work_interfere
data.loc[data['work_interfere'].isin(['Not applicable to me']),'work_interfere'] = 'Unknown'
data.loc[data['work_interfere'].isin(['Often','Sometimes']),'work_interfere'] = 'Yes'
data.loc[data['work_interfere'].isin(['Rarely','Never']),'work_interfere'] = 'No'

# %% [markdown]
# #### Missing values
# - Numerical features: replace by mean
# - Categorical features: replace by 'Missing'
#
# *Note*: Save a dictionary with the imputation value of each feature.

# %%
data.isnull().sum(axis=0)
# Out:
# Age                            11
# anonymity                     287
# benefits                      370
# care_options                  420
# coworkers                     287
# family_history                  0
# Gender                          3
# leave                         287
# mental_health_consequence     287
# mental_health_interview         0
# mental_vs_physical            287
# no_employees                  287
# obs_consequence               287
# phys_health_consequence       287
# phys_health_interview           0
# remote_work                     0
# seek_help                    1146
# self_employed                  18
# supervisor                    287
# tech_company                  287
# treatment                       0
# wellness_program              287
# work_interfere                264
# dtype: int64

# %%
target = 'treatment'
missings = {}
for feature in data.columns:
    if data[feature].dtypes in ['int','int32','int64','float','float32','float64'] and feature!=target:
        missings[feature] = data[feature].mean()
        data[feature] = data[feature].replace(np.nan,missings[feature])
    elif feature!=target:
        missings[feature] = 'Missing'
        data[feature] = data[feature].replace(np.nan,missings[feature])

# %% [markdown]
# #### Convert categorical features to category type

# %%
data.dtypes
# Out:
# Age                          float64
# anonymity                     object
# benefits                      object
# care_options                  object
# coworkers                     object
# family_history                object
# Gender                        object
# leave                         object
# mental_health_consequence     object
# mental_health_interview       object
# mental_vs_physical            object
# no_employees                  object
# obs_consequence               object
# phys_health_consequence       object
# phys_health_interview         object
# remote_work                   object
# seek_help                     object
# self_employed                 object
# supervisor                    object
# tech_company                  object
# treatment                      int64
# wellness_program              object
# work_interfere                object
# dtype: object

# %%
for feature in data.columns:
    if data[feature].dtypes not in ['int','int32','int64','float','float32','float64'] and feature!=target:
        data[feature] = data[feature].astype('category')

# %% [markdown]
# #### Save preprocessed data
# *Note*: Save preprocessed data before normalization and one hot encoding, we will use it in the notebook *5. Predicting a new instance*.

# %%
pickle.dump([data],open('Data/data.dat','wb'))

# %% [markdown]
# #### Normalization of numerical features
#
# *Note:* Save a dictionary with the mean and standard deviation used for the normalization of each feature.

# %%
normalization = {}
for feature in data.columns:
    if data[feature].dtypes in ['int','int32','int64','float','float32','float64'] and feature!=target:
        mean = data[feature].mean()
        std = data[feature].std()
        data[feature] = data[feature].apply(lambda x: (x-mean)/(std))
        normalization[feature] = (mean,std)

# %% [markdown]
# #### One hot encoding of categorical features
#
# Note: Save a dictionary with the levels or values of each feature.

# %%
one_hot_encoding = {}
for feature in data.columns:
    if str(data[feature].dtypes)=='category' and feature!=target:
        one_hot_encoding[feature] = data[feature].cat.categories
        for level in one_hot_encoding[feature]:
            data[feature+'_'+level] = (data[feature]==level).astype('int')
        data = data.drop(columns=feature)

# %%
data.T
# Out:
#                                     0         1         2         3     \
# Age                              0.49662  1.396067 -0.145842 -0.274334
# treatment                        1.00000  0.000000  0.000000  1.000000
# anonymity_Missing                0.00000  0.000000  0.000000  0.000000
# anonymity_No                     0.00000  0.000000  0.000000  1.000000
# anonymity_Unknown                0.00000  1.000000  1.000000  0.000000
# anonymity_Yes                    1.00000  0.000000  0.000000  0.000000
# benefits_Missing                 0.00000  0.000000  0.000000  0.000000
# benefits_No                      0.00000  0.000000  1.000000  1.000000
# benefits_Unknown                 0.00000  1.000000  0.000000  0.000000
# benefits_Yes                     1.00000  0.000000  0.000000  0.000000
# care_options_Missing             0.00000  0.000000  0.000000  0.000000
# care_options_No                  0.00000  1.000000  1.000000  0.000000
# care_options_Unknown             1.00000  0.000000  0.000000  0.000000
# care_options_Yes                 0.00000  0.000000  0.000000  1.000000
# coworkers_Maybe                  0.00000  0.000000  0.000000  0.000000
# coworkers_Missing                0.00000  0.000000  0.000000  0.000000
# coworkers_No                     0.00000  1.000000  0.000000  0.000000
# coworkers_Yes                    1.00000  0.000000  1.000000  1.000000
# family_history_No                1.00000  1.000000  1.000000  0.000000
# family_history_Unknown           0.00000  0.000000  0.000000  0.000000
# family_history_Yes               0.00000  0.000000  0.000000  1.000000
# Gender_Female                    1.00000  0.000000  0.000000  0.000000
# Gender_Homosexual                0.00000  0.000000  0.000000  0.000000
# Gender_Male                      0.00000  1.000000  1.000000  1.000000
# Gender_Missing                   0.00000  0.000000  0.000000  0.000000
# leave_Difficult                  0.00000  0.000000  1.000000  1.000000
# leave_Easy                       1.00000  0.000000  0.000000  0.000000
# leave_Missing                    0.00000  0.000000  0.000000  0.000000
# leave_Unknown                    0.00000  1.000000  0.000000  0.000000
# mental_health_consequence_Maybe  0.00000  1.000000  0.000000  0.000000
# ...                                  ...       ...       ...       ...
# phys_health_consequence_Missing  0.00000  0.000000  0.000000  0.000000
# phys_health_consequence_No       1.00000  1.000000  1.000000  0.000000
# phys_health_consequence_Yes      0.00000  0.000000  0.000000  1.000000
# phys_health_interview_Maybe      1.00000  0.000000  0.000000  1.000000
# phys_health_interview_No         0.00000  1.000000  0.000000  0.000000
# phys_health_interview_Yes        0.00000  0.000000  1.000000  0.000000
# remote_work_No                   1.00000  1.000000  1.000000  1.000000
# remote_work_Yes                  0.00000  0.000000  0.000000  0.000000
# seek_help_Missing                0.00000  0.000000  0.000000  0.000000
# seek_help_No                     0.00000  0.000000  1.000000  1.000000
# seek_help_Unknown                0.00000  1.000000  0.000000  0.000000
# seek_help_Yes                    1.00000  0.000000  0.000000  0.000000
# self_employed_Missing            1.00000  1.000000  1.000000  1.000000
# self_employed_No                 0.00000  0.000000  0.000000  0.000000
# self_employed_Yes                0.00000  0.000000  0.000000  0.000000
# supervisor_Maybe                 0.00000  0.000000  0.000000  0.000000
# supervisor_Missing               0.00000  0.000000  0.000000  0.000000
# supervisor_No                    0.00000  1.000000  0.000000  1.000000
# supervisor_Yes                   1.00000  0.000000  1.000000  0.000000
# tech_company_Missing             0.00000  0.000000  0.000000  0.000000
# tech_company_No                  0.00000  1.000000  0.000000  0.000000
# tech_company_Yes                 1.00000  0.000000  1.000000  1.000000
# wellness_program_Missing         0.00000  0.000000  0.000000  0.000000
# wellness_program_No              1.00000  0.000000  1.000000  1.000000
# wellness_program_Unknown         0.00000  1.000000  0.000000  0.000000
# wellness_program_Yes             0.00000  0.000000  0.000000  0.000000
# work_interfere_Missing           0.00000  0.000000  0.000000  0.000000
# work_interfere_No                0.00000  1.000000  1.000000  0.000000
# work_interfere_Unknown           0.00000  0.000000  0.000000  0.000000
# work_interfere_Yes               1.00000  0.000000  0.000000  1.000000
#
#                                      4        5         6         7     \
# Age                             -0.274334 -0.01735  0.239635  0.753605
# treatment                        0.000000  0.00000  1.000000  0.000000
# anonymity_Missing                0.000000  0.00000  0.000000  0.000000
# anonymity_No                     0.000000  0.00000  1.000000  0.000000
# anonymity_Unknown                1.000000  1.00000  0.000000  0.000000
# anonymity_Yes                    0.000000  0.00000  0.000000  1.000000
# benefits_Missing                 0.000000  0.00000  0.000000  0.000000
# benefits_No                      0.000000  0.00000  1.000000  1.000000
# benefits_Unknown                 0.000000  0.00000  0.000000  0.000000
# benefits_Yes                     1.000000  1.00000  0.000000  0.000000
# care_options_Missing             0.000000  0.00000  0.000000  0.000000
# care_options_No                  1.000000  0.00000  1.000000  0.000000
# care_options_Unknown             0.000000  1.00000  0.000000  0.000000
# care_options_Yes                 0.000000  0.00000  0.000000  1.000000
# coworkers_Maybe                  0.000000  0.00000  0.000000  0.000000
# coworkers_Missing                0.000000  0.00000  0.000000  0.000000
# coworkers_No                     0.000000  0.00000  0.000000  1.000000
# coworkers_Yes                    1.000000  1.00000  1.000000  0.000000
# family_history_No                1.000000  0.00000  0.000000  1.000000
# family_history_Unknown           0.000000  0.00000  0.000000  0.000000
# family_history_Yes               0.000000  1.00000  1.000000  0.000000
# Gender_Female                    0.000000  0.00000  1.000000  0.000000
# Gender_Homosexual                0.000000  0.00000  0.000000  0.000000
# Gender_Male                      1.000000  1.00000  0.000000  1.000000
# Gender_Missing                   0.000000  0.00000  0.000000  0.000000
# leave_Difficult                  0.000000  0.00000  1.000000  0.000000
# leave_Easy                       0.000000  0.00000  0.000000  0.000000
# leave_Missing                    0.000000  0.00000  0.000000  0.000000
# leave_Unknown                    1.000000  1.00000  0.000000  1.000000
# mental_health_consequence_Maybe  0.000000  0.00000  1.000000  0.000000
# ...                                   ...      ...       ...       ...
# phys_health_consequence_Missing  0.000000  0.00000  0.000000  0.000000
# phys_health_consequence_No       1.000000  1.00000  0.000000  1.000000
# phys_health_consequence_Yes      0.000000  0.00000  0.000000  0.000000
# phys_health_interview_Maybe      0.000000  1.00000  0.000000  0.000000
# phys_health_interview_No         0.000000  0.00000  1.000000  1.000000
# phys_health_interview_Yes        1.000000  0.00000  0.000000  0.000000
# remote_work_No                   0.000000  1.00000  0.000000  0.000000
# remote_work_Yes                  1.000000  0.00000  1.000000  1.000000
# seek_help_Missing                0.000000  0.00000  0.000000  0.000000
# seek_help_No                     0.000000  0.00000  1.000000  1.000000
# seek_help_Unknown                1.000000  1.00000  0.000000  0.000000
# seek_help_Yes                    0.000000  0.00000  0.000000  0.000000
# self_employed_Missing            1.000000  1.00000  1.000000  1.000000
# self_employed_No                 0.000000  0.00000  0.000000  0.000000
# self_employed_Yes                0.000000  0.00000  0.000000  0.000000
# supervisor_Maybe                 0.000000  0.00000  0.000000  0.000000
# supervisor_Missing               0.000000  0.00000  0.000000  0.000000
# supervisor_No                    0.000000  0.00000  1.000000  1.000000
# supervisor_Yes                   1.000000  1.00000  0.000000  0.000000
# tech_company_Missing             0.000000  0.00000  0.000000  0.000000
# tech_company_No                  0.000000  0.00000  0.000000  0.000000
# tech_company_Yes                 1.000000  1.00000  1.000000  1.000000
# wellness_program_Missing         0.000000  0.00000  0.000000  0.000000
# wellness_program_No              0.000000  1.00000  1.000000  1.000000
# wellness_program_Unknown         1.000000  0.00000  0.000000  0.000000
# wellness_program_Yes             0.000000  0.00000  0.000000  0.000000
# work_interfere_Missing           0.000000  0.00000  0.000000  0.000000
# work_interfere_No                1.000000  0.00000  0.000000  1.000000
# work_interfere_Unknown           0.000000  0.00000  0.000000  0.000000
# work_interfere_Yes               0.000000  1.00000  1.000000  0.000000
#
#                                      8         9       ...         2682  \
# Age                              1.139082 -1.302274    ...    -1.173781
# treatment                        1.000000  0.000000    ...     0.000000
# anonymity_Missing                0.000000  0.000000    ...     0.000000
# anonymity_No                     1.000000  0.000000    ...     0.000000
# anonymity_Unknown                0.000000  1.000000    ...     1.000000
# anonymity_Yes                    0.000000  0.000000    ...     0.000000
# benefits_Missing                 0.000000  0.000000    ...     0.000000
# benefits_No                      0.000000  0.000000    ...     0.000000
# benefits_Unknown                 0.000000  1.000000    ...     0.000000
# benefits_Yes                     1.000000  0.000000    ...     1.000000
# care_options_Missing             0.000000  0.000000    ...     0.000000
# care_options_No                  0.000000  1.000000    ...     0.000000
# care_options_Unknown             0.000000  0.000000    ...     1.000000
# care_options_Yes                 1.000000  0.000000    ...     0.000000
# coworkers_Maybe                  0.000000  0.000000    ...     0.000000
# coworkers_Missing                0.000000  0.000000    ...     0.000000
# coworkers_No                     0.000000  0.000000    ...     1.000000
# coworkers_Yes                    1.000000  1.000000    ...     0.000000
# family_history_No                0.000000  1.000000    ...     1.000000
# family_history_Unknown           0.000000  0.000000    ...     0.000000
# family_history_Yes               1.000000  0.000000    ...     0.000000
# Gender_Female                    1.000000  0.000000    ...     0.000000
# Gender_Homosexual                0.000000  0.000000    ...     0.000000
# Gender_Male                      0.000000  1.000000    ...     1.000000
# Gender_Missing                   0.000000  0.000000    ...     0.000000
# leave_Difficult                  1.000000  0.000000    ...     0.000000
# leave_Easy                       0.000000  0.000000    ...     1.000000
# leave_Missing                    0.000000  0.000000    ...     0.000000
# leave_Unknown                    0.000000  1.000000    ...     0.000000
# mental_health_consequence_Maybe  1.000000  0.000000    ...     0.000000
# ...                                   ...       ...    ...          ...
# phys_health_consequence_Missing  0.000000  0.000000    ...     0.000000
# phys_health_consequence_No       1.000000  1.000000    ...     1.000000
# phys_health_consequence_Yes      0.000000  0.000000    ...     0.000000
# phys_health_interview_Maybe      1.000000  1.000000    ...     1.000000
# phys_health_interview_No         0.000000  0.000000    ...     0.000000
# phys_health_interview_Yes        0.000000  0.000000    ...     0.000000
# remote_work_No                   1.000000  1.000000    ...     0.000000
# remote_work_Yes                  0.000000  0.000000    ...     1.000000
# seek_help_Missing                0.000000  0.000000    ...     1.000000
# seek_help_No                     1.000000  0.000000    ...     0.000000
# seek_help_Unknown                0.000000  1.000000    ...     0.000000
# seek_help_Yes                    0.000000  0.000000    ...     0.000000
# self_employed_Missing            1.000000  1.000000    ...     0.000000
# self_employed_No                 0.000000  0.000000    ...     1.000000
# self_employed_Yes                0.000000  0.000000    ...     0.000000
# supervisor_Maybe                 0.000000  0.000000    ...     1.000000
# supervisor_Missing               0.000000  0.000000    ...     0.000000
# supervisor_No                    0.000000  0.000000    ...     0.000000
# supervisor_Yes                   1.000000  1.000000    ...     0.000000
# tech_company_Missing             0.000000  0.000000    ...     0.000000
# tech_company_No                  0.000000  0.000000    ...     0.000000
# tech_company_Yes                 1.000000  1.000000    ...     1.000000
# wellness_program_Missing         0.000000  0.000000    ...     0.000000
# wellness_program_No              1.000000  0.000000    ...     0.000000
# wellness_program_Unknown         0.000000  1.000000    ...     0.000000
# wellness_program_Yes             0.000000  0.000000    ...     1.000000
# work_interfere_Missing           0.000000  0.000000    ...     0.000000
# work_interfere_No                0.000000  1.000000    ...     0.000000
# work_interfere_Unknown           0.000000  0.000000    ...     1.000000
# work_interfere_Yes               1.000000  0.000000    ...     0.000000
#
#                                      2683      2684      2685      2686  \
# Age                             -1.430766 -1.173781 -0.916797  0.625113
# treatment                        1.000000  0.000000  1.000000  1.000000
# anonymity_Missing                0.000000  0.000000  0.000000  0.000000
# anonymity_No                     0.000000  0.000000  0.000000  0.000000
# anonymity_Unknown                1.000000  0.000000  1.000000  0.000000
# anonymity_Yes                    0.000000  1.000000  0.000000  1.000000
# benefits_Missing                 1.000000  0.000000  0.000000  0.000000
# benefits_No                      0.000000  0.000000  0.000000  0.000000
# benefits_Unknown                 0.000000  0.000000  1.000000  0.000000
# benefits_Yes                     0.000000  1.000000  0.000000  1.000000
# care_options_Missing             1.000000  0.000000  0.000000  0.000000
# care_options_No                  0.000000  0.000000  0.000000  1.000000
# care_options_Unknown             0.000000  1.000000  1.000000  0.000000
# care_options_Yes                 0.000000  0.000000  0.000000  0.000000
# coworkers_Maybe                  1.000000  1.000000  1.000000  0.000000
# coworkers_Missing                0.000000  0.000000  0.000000  0.000000
# coworkers_No                     0.000000  0.000000  0.000000  0.000000
# coworkers_Yes                    0.000000  0.000000  0.000000  1.000000
# family_history_No                0.000000  0.000000  0.000000  0.000000
# family_history_Unknown           1.000000  1.000000  1.000000  0.000000
# family_history_Yes               0.000000  0.000000  0.000000  1.000000
# Gender_Female                    1.000000  0.000000  1.000000  1.000000
# Gender_Homosexual                0.000000  0.000000  0.000000  0.000000
# Gender_Male                      0.000000  1.000000  0.000000  0.000000
# Gender_Missing                   0.000000  0.000000  0.000000  0.000000
# leave_Difficult                  1.000000  0.000000  0.000000  0.000000
# leave_Easy                       0.000000  1.000000  1.000000  1.000000
# leave_Missing                    0.000000  0.000000  0.000000  0.000000
# leave_Unknown                    0.000000  0.000000  0.000000  0.000000
# mental_health_consequence_Maybe  1.000000  0.000000  1.000000  0.000000
# ...                                   ...       ...       ...       ...
# phys_health_consequence_Missing  0.000000  0.000000  0.000000  0.000000
# phys_health_consequence_No       1.000000  1.000000  1.000000  1.000000
# phys_health_consequence_Yes      0.000000  0.000000  0.000000  0.000000
# phys_health_interview_Maybe      1.000000  1.000000  1.000000  0.000000
# phys_health_interview_No         0.000000  0.000000  0.000000  1.000000
# phys_health_interview_Yes        0.000000  0.000000  0.000000  0.000000
# remote_work_No                   0.000000  0.000000  0.000000  0.000000
# remote_work_Yes                  1.000000  1.000000  1.000000  1.000000
# seek_help_Missing                1.000000  1.000000  1.000000  1.000000
# seek_help_No                     0.000000  0.000000  0.000000  0.000000
# seek_help_Unknown                0.000000  0.000000  0.000000  0.000000
# seek_help_Yes                    0.000000  0.000000  0.000000  0.000000
# self_employed_Missing            0.000000  0.000000  0.000000  0.000000
# self_employed_No                 1.000000  1.000000  1.000000  1.000000
# self_employed_Yes                0.000000  0.000000  0.000000  0.000000
# supervisor_Maybe                 1.000000  0.000000  1.000000  0.000000
# supervisor_Missing               0.000000  0.000000  0.000000  0.000000
# supervisor_No                    0.000000  0.000000  0.000000  0.000000
# supervisor_Yes                   0.000000  1.000000  0.000000  1.000000
# tech_company_Missing             0.000000  0.000000  0.000000  0.000000
# tech_company_No                  0.000000  0.000000  0.000000  0.000000
# tech_company_Yes                 1.000000  1.000000  1.000000  1.000000
# wellness_program_Missing         0.000000  0.000000  0.000000  0.000000
# wellness_program_No              1.000000  0.000000  1.000000  1.000000
# wellness_program_Unknown         0.000000  0.000000  0.000000  0.000000
# wellness_program_Yes             0.000000  1.000000  0.000000  0.000000
# work_interfere_Missing           0.000000  0.000000  0.000000  0.000000
# work_interfere_No                1.000000  1.000000  1.000000  1.000000
# work_interfere_Unknown           0.000000  0.000000  0.000000  0.000000
# work_interfere_Yes               0.000000  0.000000  0.000000  0.000000
#
#                                      2687      2688      2689      2690  \
# Age                              0.111143  2.937976  2.424007 -0.402827
# treatment                        1.000000  0.000000  1.000000  0.000000
# anonymity_Missing                1.000000  1.000000  0.000000  0.000000
# anonymity_No                     0.000000  0.000000  0.000000  0.000000
# anonymity_Unknown                0.000000  0.000000  1.000000  1.000000
# anonymity_Yes                    0.000000  0.000000  0.000000  0.000000
# benefits_Missing                 1.000000  1.000000  0.000000  0.000000
# benefits_No                      0.000000  0.000000  0.000000  0.000000
# benefits_Unknown                 0.000000  0.000000  0.000000  1.000000
# benefits_Yes                     0.000000  0.000000  1.000000  0.000000
# care_options_Missing             1.000000  1.000000  0.000000  0.000000
# care_options_No                  0.000000  0.000000  0.000000  0.000000
# care_options_Unknown             0.000000  0.000000  0.000000  1.000000
# care_options_Yes                 0.000000  0.000000  1.000000  0.000000
# coworkers_Maybe                  0.000000  0.000000  0.000000  1.000000
# coworkers_Missing                1.000000  1.000000  0.000000  0.000000
# coworkers_No                     0.000000  0.000000  0.000000  0.000000
# coworkers_Yes                    0.000000  0.000000  1.000000  0.000000
# family_history_No                0.000000  0.000000  0.000000  0.000000
# family_history_Unknown           0.000000  0.000000  0.000000  0.000000
# family_history_Yes               1.000000  1.000000  1.000000  1.000000
# Gender_Female                    1.000000  0.000000  0.000000  1.000000
# Gender_Homosexual                0.000000  0.000000  0.000000  0.000000
# Gender_Male                      0.000000  1.000000  1.000000  0.000000
# Gender_Missing                   0.000000  0.000000  0.000000  0.000000
# leave_Difficult                  0.000000  0.000000  1.000000  1.000000
# leave_Easy                       0.000000  0.000000  0.000000  0.000000
# leave_Missing                    1.000000  1.000000  0.000000  0.000000
# leave_Unknown                    0.000000  0.000000  0.000000  0.000000
# mental_health_consequence_Maybe  0.000000  0.000000  1.000000  1.000000
# ...                                   ...       ...       ...       ...
# phys_health_consequence_Missing  1.000000  1.000000  0.000000  0.000000
# phys_health_consequence_No       0.000000  0.000000  0.000000  1.000000
# phys_health_consequence_Yes      0.000000  0.000000  0.000000  0.000000
# phys_health_interview_Maybe      0.000000  1.000000  1.000000  1.000000
# phys_health_interview_No         1.000000  0.000000  0.000000  0.000000
# phys_health_interview_Yes        0.000000  0.000000  0.000000  0.000000
# remote_work_No                   0.000000  0.000000  0.000000  0.000000
# remote_work_Yes                  1.000000  1.000000  1.000000  1.000000
# seek_help_Missing                0.000000  0.000000  1.000000  1.000000
# seek_help_No                     0.000000  0.000000  0.000000  0.000000
# seek_help_Unknown                0.000000  0.000000  0.000000  0.000000
# seek_help_Yes                    1.000000  1.000000  0.000000  0.000000
# self_employed_Missing            0.000000  0.000000  0.000000  0.000000
# self_employed_No                 0.000000  0.000000  1.000000  1.000000
# self_employed_Yes                1.000000  1.000000  0.000000  0.000000
# supervisor_Maybe                 0.000000  0.000000  0.000000  0.000000
# supervisor_Missing               1.000000  1.000000  0.000000  0.000000
# supervisor_No                    0.000000  0.000000  0.000000  0.000000
# supervisor_Yes                   0.000000  0.000000  1.000000  1.000000
# tech_company_Missing             1.000000  1.000000  0.000000  0.000000
# tech_company_No                  0.000000  0.000000  0.000000  1.000000
# tech_company_Yes                 0.000000  0.000000  1.000000  0.000000
# wellness_program_Missing         1.000000  1.000000  0.000000  0.000000
# wellness_program_No              0.000000  0.000000  0.000000  1.000000
# wellness_program_Unknown         0.000000  0.000000  0.000000  0.000000
# wellness_program_Yes             0.000000  0.000000  1.000000  0.000000
# work_interfere_Missing           0.000000  0.000000  0.000000  0.000000
# work_interfere_No                0.000000  0.000000  1.000000  0.000000
# work_interfere_Unknown           1.000000  0.000000  0.000000  0.000000
# work_interfere_Yes               0.000000  1.000000  0.000000  1.000000
#
#                                      2691
# Age                             -1.045289
# treatment                        0.000000
# anonymity_Missing                0.000000
# anonymity_No                     0.000000
# anonymity_Unknown                1.000000
# anonymity_Yes                    0.000000
# benefits_Missing                 0.000000
# benefits_No                      0.000000
# benefits_Unknown                 0.000000
# benefits_Yes                     1.000000
# care_options_Missing             0.000000
# care_options_No                  1.000000
# care_options_Unknown             0.000000
# care_options_Yes                 0.000000
# coworkers_Maybe                  1.000000
# coworkers_Missing                0.000000
# coworkers_No                     0.000000
# coworkers_Yes                    0.000000
# family_history_No                0.000000
# family_history_Unknown           1.000000
# family_history_Yes               0.000000
# Gender_Female                    0.000000
# Gender_Homosexual                1.000000
# Gender_Male                      0.000000
# Gender_Missing                   0.000000
# leave_Difficult                  1.000000
# leave_Easy                       0.000000
# leave_Missing                    0.000000
# leave_Unknown                    0.000000
# mental_health_consequence_Maybe  1.000000
# ...                                   ...
# phys_health_consequence_Missing  0.000000
# phys_health_consequence_No       1.000000
# phys_health_consequence_Yes      0.000000
# phys_health_interview_Maybe      1.000000
# phys_health_interview_No         0.000000
# phys_health_interview_Yes        0.000000
# remote_work_No                   0.000000
# remote_work_Yes                  1.000000
# seek_help_Missing                1.000000
# seek_help_No                     0.000000
# seek_help_Unknown                0.000000
# seek_help_Yes                    0.000000
# self_employed_Missing            0.000000
# self_employed_No                 1.000000
# self_employed_Yes                0.000000
# supervisor_Maybe                 1.000000
# supervisor_Missing               0.000000
# supervisor_No                    0.000000
# supervisor_Yes                   0.000000
# tech_company_Missing             0.000000
# tech_company_No                  0.000000
# tech_company_Yes                 1.000000
# wellness_program_Missing         0.000000
# wellness_program_No              1.000000
# wellness_program_Unknown         0.000000
# wellness_program_Yes             0.000000
# work_interfere_Missing           0.000000
# work_interfere_No                0.000000
# work_interfere_Unknown           1.000000
# work_interfere_Yes               0.000000
#
# [79 rows x 2692 columns]

# %% [markdown]
# #### Save preprocessing dictionaries
# - missings
# - normalization
# - one_hot_encoding

# %%
pickle.dump([missings,normalization,one_hot_encoding],open('Data/preprocessing_dictionaries.dat','wb'))

# %% [markdown]
# #### Split data
# - 50% in *train* for modelling 1st stacking layer
# - 25% in *validation* for validating 1st stacking layer models and modelling 2nd using the predictions of 1st stacking layer as features
# - 25% in *test* for validating 2nd stacking layers models
#
# *Note:* We will use balanced splitting for getting same binary target distribution (same % of 1) in each split.

# %%
def split_balanced(indexes,target,fractions=[0.5,0.25,0.25],seed=1):
    indexes = np.array(indexes)
    labels = np.unique(target)
    fractions = np.cumsum(fractions)
    train_index = np.array([])
    validation_index = np.array([])
    test_index = np.array([])
    for label in labels:
        np.random.seed(seed)
        label_indexes = np.random.permutation(indexes[target==label])
        n = len(label_indexes)
        n_train = int(n*fractions[0])
        n_validation = int(n*fractions[1])
        train_index = np.concatenate((train_index,label_indexes[:n_train]))
        validation_index = np.concatenate((validation_index,label_indexes[n_train:n_validation]))
        test_index = np.concatenate((test_index,label_indexes[n_validation:]))
    return(train_index,validation_index,test_index)

train_index,validation_index,test_index = split_balanced(data.index,data['treatment'],[0.5,0.25,0.25],1)
train,validation,test = data.loc[train_index],data.loc[validation_index],data.loc[test_index]

# %% [markdown]
# #### Save preprocessed data splits

# %%
pickle.dump([train,validation,test],open('Data/data_splits.dat','wb'))
